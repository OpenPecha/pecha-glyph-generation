# %%
pip install pillow
# Out:
# Requirement already satisfied: pillow in /opt/homebrew/Cellar/jupyterlab/4.2.3/libexec/lib/python3.12/site-packages (10.4.0)
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from PIL import Image, ImageDraw, ImageFont

cleaned_images_dir = '../../data/derge_glyph_images'
condition_dir = '../../data/condition_images'
font_path = '../../data/MonlamTBslim.ttf'
image_size = (256, 256)
font_size = 80  

os.makedirs(condition_dir, exist_ok=True)

font = ImageFont.truetype(font_path, font_size)

def create_glyph_image(glyph, save_path):
    # Create a blank image with white background
    image = Image.new('RGB', image_size, 'white')
    draw = ImageDraw.Draw(image)
    
    # Get the bounding box of the glyph
    bbox = draw.textbbox((0, 0), glyph, font=font)
    text_width = bbox[2] - bbox[0]
    text_height = bbox[3] - bbox[1]
    
    # Calculate the center of mass of the glyph
    cx = bbox[0] + text_width / 2
    cy = bbox[1] + text_height / 2
    
    # Calculate the position to center the center of mass of the glyph
    x = (image_size[0] / 2) - cx
    y = (image_size[1] / 2) - cy
    
    # Draw the glyph on the image
    draw.text((x, y), glyph, font=font, fill='black')
    
    # Save the image
    image.save(save_path)

# Process each image in the cleaned_images folder
for image_file in os.listdir(cleaned_images_dir):
    if image_file.endswith('.png'):
        # Extract the glyph by splitting the filename on underscores and taking the second element
        glyph = image_file.split('_')[1].split('.')[0]
        save_path = os.path.join(condition_dir, image_file)
        try:
            create_glyph_image(glyph, save_path)
            print(f"Created glyph image for {image_file}")
        except Exception as e:
            print(f"Error creating glyph image for {image_file}: {e}")

print("Glyph image creation completed.")
# Out:
# Created glyph image for derge_པི_12.png
# Created glyph image for derge_ཊུ_29.png
# Created glyph image for derge_ཧྲ_51.png
# Created glyph image for derge_སྤྲུ_31.png
# Created glyph image for derge_ནྡྲ_76.png
# Created glyph image for derge_ྶ_1.png
# Created glyph image for derge_ཙི_19.png
# Created glyph image for derge_རུ_22.png
# Created glyph image for derge_སྭ_60.png
# Created glyph image for derge_ཏྣ_100.png
# Created glyph image for derge_དྨ_10.png
# Created glyph image for derge_ཙོ_20.png
# Created glyph image for derge_ཎྜ_15.png
# Created glyph image for derge_ཇུ_22.png
# Created glyph image for derge_ནྡྲ_89.png
# Created glyph image for derge_ཀྐུ_7.png
# Created glyph image for derge_ུ_20.png
# Created glyph image for derge_ཁྲུ_13.png
# Created glyph image for derge_སྒུ_19.png
# Created glyph image for derge_བུ_16.png
# Created glyph image for derge_ཀཾ_17.png
# Created glyph image for derge_ཅྭ_19.png
# Created glyph image for derge_ཛེ_18.png
# Created glyph image for derge_ཙ_13.png
# Created glyph image for derge_ནྱཱ_1.png
# Created glyph image for derge_སྡུ_100.png
# Created glyph image for derge_ཟླ_100.png
# Created glyph image for derge_སྟུ_12.png
# Created glyph image for derge_འི_26.png
# Created glyph image for derge_ནྲ_71.png
# Created glyph image for derge_སྨཱ_62.png
# Created glyph image for derge_བེ_13.png
# Created glyph image for derge_ནཱ_17.png
# Created glyph image for derge_ནྡྷ_1.png
# Created glyph image for derge_སྐྱུ_20.png
# Created glyph image for derge_ཎྜཱ_8.png
# Created glyph image for derge_རྩྭ_17.png
# Created glyph image for derge_གྒ_36.png
# Created glyph image for derge_རྟུ_18.png
# Created glyph image for derge_༑_2.png
# Created glyph image for derge_ངྒཱ_18.png
# Created glyph image for derge_རྐ_16.png
# Created glyph image for derge_པྲ_19.png
# Created glyph image for derge_སྩ_10.png
# Created glyph image for derge_ལྷ_41.png
# Created glyph image for derge_དྷ_18.png
# Created glyph image for derge_ནྦཱ.png
# Created glyph image for derge_ཟོ_2.png
# Created glyph image for derge_ཥྛཱ_51.png
# Created glyph image for derge_ཕོ_12.png
# Created glyph image for derge_མྦྷ_39.png
# Created glyph image for derge_མྱུ_12.png
# Created glyph image for derge_ངྐ_2.png
# Created glyph image for derge_པྲ_25.png
# Created glyph image for derge_ར_18.png
# Created glyph image for derge_བི_1.png
# Created glyph image for derge_ཁུ_100.png
# Created glyph image for derge_ཁ_12.png
# Created glyph image for derge_རྫུ_10.png
# Created glyph image for derge_ྭ_1.png
# Created glyph image for derge_ཉོ_11.png
# Created glyph image for derge_ནྟ_1.png
# Created glyph image for derge_ཤྩཱ.png
# Created glyph image for derge_པྟ_8.png
# Created glyph image for derge_རྦུ_33.png
# Created glyph image for derge_ཀུ_100.png
# Created glyph image for derge_ཉི_14.png
# Created glyph image for derge_སྐྲ_2.png
# Created glyph image for derge_དེ_1.png
# Created glyph image for derge_རྱ_19.png
# Created glyph image for derge_ནྡྷུ_14.png
# Created glyph image for derge_སྦྱ_16.png
# Created glyph image for derge_སེ_13.png
# Created glyph image for derge_ཧཱུཾ_16.png
# Created glyph image for derge_རྒ_13.png
# Created glyph image for derge_ཎ_2.png
# Created glyph image for derge_ཧྞ_36.png
# Created glyph image for derge_རྩུ_100.png
# Created glyph image for derge_རྭ_40.png
# Created glyph image for derge_མྦ_8.png
# Created glyph image for derge_སུ_16.png
# Created glyph image for derge_དྲ_14.png
# Created glyph image for derge_ྲ_5.png
# Created glyph image for derge_གྲྭ_22.png
# Created glyph image for derge_ཧ_14.png
# Created glyph image for derge_ཛྱ_32.png
# Created glyph image for derge_པྤ.png
# Created glyph image for derge_ྫ_7.png
# Created glyph image for derge_ཁོ_17.png
# Created glyph image for derge_ཛྫཱ_23.png
# Created glyph image for derge_དྷུ_13.png
# Created glyph image for derge_བྷཱུ_66.png
# Created glyph image for derge_༅_28.png
# Created glyph image for derge_ྜ_8.png
# Created glyph image for derge_སྐྲུ_68.png
# Created glyph image for derge_ཤི_12.png
# Created glyph image for derge_གྨཱ.png
# Created glyph image for derge_ཤྭ_11.png
# Created glyph image for derge_གྡྲ.png
# Created glyph image for derge_ཀྵ_15.png
# Created glyph image for derge_ཁྭ_11.png
# Created glyph image for derge_མཱུ_56.png
# Created glyph image for derge_ཟེ_10.png
# Created glyph image for derge_སླུ_11.png
# Created glyph image for derge_ཏུ_18.png
# Created glyph image for derge_སྙ_12.png
# Created glyph image for derge_ཧེ_16.png
# Created glyph image for derge_གེ_16.png
# Created glyph image for derge_དྲཱ_9.png
# Created glyph image for derge_ནྜཱ.png
# Created glyph image for derge_མྱ_100.png
# Created glyph image for derge_ཀྶ.png
# Created glyph image for derge_སྦྲུ_2.png
# Created glyph image for derge_བླ_2.png
# Created glyph image for derge_ལྕ_37.png
# Created glyph image for derge_རྩ_30.png
# Created glyph image for derge_རྒྱ_14.png
# Created glyph image for derge_སླ_14.png
# Created glyph image for derge_ཌྷ_2.png
# Created glyph image for derge_ཛྱཱ_7.png
# Created glyph image for derge_རྱཱ.png
# Created glyph image for derge_ཎྜཱུ.png
# Created glyph image for derge_ྩ_5.png
# Created glyph image for derge_ཛ_16.png
# Created glyph image for derge_ཞུ_10.png
# Created glyph image for derge_དཱ_100.png
# Created glyph image for derge_ཤཱུ_6.png
# Created glyph image for derge_ངྷ_18.png
# Created glyph image for derge_སཱུ_24.png
# Created glyph image for derge_ཕྱུ_100.png
# Created glyph image for derge_ནེ_22.png
# Created glyph image for derge_ཧཱུ_30.png
# Created glyph image for derge_ཕ_13.png
# Created glyph image for derge_ཁྲ_19.png
# Created glyph image for derge_སྲུ_14.png
# Created glyph image for derge_ཞེ_15.png
# Created glyph image for derge_སཱུ_30.png
# Created glyph image for derge_ཨི_20.png
# Created glyph image for derge_ཨི_21.png
# Created glyph image for derge_སཱུ_31.png
# Created glyph image for derge_ནེ_23.png
# Created glyph image for derge_སི_2.png
# Created glyph image for derge_གི_1.png
# Created glyph image for derge_དྡྷ_14.png
# Created glyph image for derge_ཀི_16.png
# Created glyph image for derge_སཱུ_25.png
# Created glyph image for derge_ཞེ_14.png
# Created glyph image for derge_ཕ_12.png
# Created glyph image for derge_ཟླ_16.png
# Created glyph image for derge_ཞུ_11.png
# Created glyph image for derge_ཎྞཱ_28.png
# Created glyph image for derge_ཧཱུ_19.png
# Created glyph image for derge_༈_69.png
# Created glyph image for derge_ཎུ_7.png
# Created glyph image for derge_སཱུ_19.png
# Created glyph image for derge_ཛྱཱ_6.png
# Created glyph image for derge_ྩ_4.png
# Created glyph image for derge_རྠ_15.png
# Created glyph image for derge_ལྦ_2.png
# Created glyph image for derge_སླ_15.png
# Created glyph image for derge_རྒྱ_15.png
# Created glyph image for derge_རྒ_100.png
# Created glyph image for derge_ཧྣ_2.png
# Created glyph image for derge_ལྱ_21.png
# Created glyph image for derge_ཊྐཱ.png
# Created glyph image for derge_རྩ_25.png
# Created glyph image for derge_སྦྲུ_3.png
# Created glyph image for derge_གེ_17.png
# Created glyph image for derge_དྱུ_1.png
# Created glyph image for derge_ཧེ_17.png
# Created glyph image for derge_སྙ_13.png
# Created glyph image for derge_ཧྣཱ.png
# Created glyph image for derge_བྷུ_88.png
# Created glyph image for derge_ཙྩུ.png
# Created glyph image for derge_ོ_45.png
# Created glyph image for derge_ནྡུ_1.png
# Created glyph image for derge_སླུ_10.png
# Created glyph image for derge_ཤྭ_10.png
# Created glyph image for derge_མཱུ_43.png
# Created glyph image for derge_ཁྲ_100.png
# Created glyph image for derge_ཥཱ_47.png
# Created glyph image for derge_བྱ_10.png
# Created glyph image for derge_ཏྠཱ_43.png
# Created glyph image for derge_དྐཱ.png
# Created glyph image for derge_ཤོ_16.png
# Created glyph image for derge_ྜ_9.png
# Created glyph image for derge_ཛྱ_27.png
# Created glyph image for derge_༅_29.png
# Created glyph image for derge_བྷཱུ_67.png
# Created glyph image for derge_ྫ_6.png
# Created glyph image for derge_ཀྲ_100.png
# Created glyph image for derge_ཤྲཱ_5.png
# Created glyph image for derge_ཧ_15.png
# Created glyph image for derge_ཁོ_16.png
# Created glyph image for derge_བྱ_1.png
# Created glyph image for derge_གྲྭ_23.png
# Created glyph image for derge_གླ_10.png
# Created glyph image for derge_ཉི_100.png
# Created glyph image for derge_ྲ_4.png
# Created glyph image for derge_སེ_12.png
# Created glyph image for derge_ཕོ_100.png
# Created glyph image for derge_སྦྱ_17.png
# Created glyph image for derge_རྤཱ.png
# Created glyph image for derge_ཧཱུཾ_17.png
# Created glyph image for derge_སོ_100.png
# Created glyph image for derge_ཛྫ_9.png
# Created glyph image for derge_ཧོ_100.png
# Created glyph image for derge_ཉི_15.png
# Created glyph image for derge_ཉོ_10.png
# Created glyph image for derge_པྟ_9.png
# Created glyph image for derge_ར_19.png
# Created glyph image for derge_ཀླུ_17.png
# Created glyph image for derge_རྫུ_11.png
# Created glyph image for derge_ཁ_13.png
# Created glyph image for derge_ྞ_10.png
# Created glyph image for derge_ག_100.png
# Created glyph image for derge_གྱ_15.png
# Created glyph image for derge_པྲ_24.png
# Created glyph image for derge_ཀཾ_9.png
# Created glyph image for derge_ལྷུ_12.png
# Created glyph image for derge_སྩ_11.png
# Created glyph image for derge_ཧ_100.png
# Created glyph image for derge_ཎྜཱ_65.png
# Created glyph image for derge_པྟ_17.png
# Created glyph image for derge_རྞ_12.png
# Created glyph image for derge_ཕོ_13.png
# Created glyph image for derge_ྴ_2.png
# Created glyph image for derge_རྐ_17.png
# Created glyph image for derge_ངྒཱ_19.png
# Created glyph image for derge_ནྟྲ_20.png
# Created glyph image for derge_ལྟུ_19.png
# Created glyph image for derge_མི_21.png
# Created glyph image for derge_གྒ_23.png
# Created glyph image for derge_ཀྵྲཱ.png
# Created glyph image for derge_མྱུ_2.png
# Created glyph image for derge_པྲ_18.png
# Created glyph image for derge_རྙ_27.png
# Created glyph image for derge_སྐྱུ_21.png
# Created glyph image for derge_མོ_18.png
# Created glyph image for derge_རྟུ_19.png
# Created glyph image for derge_བེ_12.png
# Created glyph image for derge_སྒུ_30.png
# Created glyph image for derge_ཥྚཱ_3.png
# Created glyph image for derge_སྨྲ_11.png
# Created glyph image for derge_སྨ_1.png
# Created glyph image for derge_ཅྭ_18.png
# Created glyph image for derge_ཙ_12.png
# Created glyph image for derge_ཛེ_19.png
# Created glyph image for derge_ཏྨྱ.png
# Created glyph image for derge_བུ_17.png
# Created glyph image for derge_ཨུ_1.png
# Created glyph image for derge_ཁྲུ_12.png
# Created glyph image for derge_དྷ_100.png
# Created glyph image for derge_དྨ_11.png
# Created glyph image for derge_ཙོ_21.png
# Created glyph image for derge_པཱུ_19.png
# Created glyph image for derge_སྭ_61.png
# Created glyph image for derge_པོ_16.png
# Created glyph image for derge_ཇུ_23.png
# Created glyph image for derge_ཇོ_2.png
# Created glyph image for derge_སྒྲ_100.png
# Created glyph image for derge_ཅེ_1.png
# Created glyph image for derge_རྒྱུ_22.png
# Created glyph image for derge_པྲཱ_5.png
# Created glyph image for derge_རྞཱ.png
# Created glyph image for derge_ཕྲུ_29.png
# Created glyph image for derge_ཎྱ_27.png
# Created glyph image for derge_ཙི_18.png
# Created glyph image for derge_ཊུ_28.png
# Created glyph image for derge_རྴ_3.png
# Created glyph image for derge_སྤྲུ_30.png
# Created glyph image for derge_ཧྲ_50.png
# Created glyph image for derge_ཧྲུ_1.png
# Created glyph image for derge_སྔུ_49.png
# Created glyph image for derge_ལླཱ_16.png
# Created glyph image for derge_ཏྤྲ.png
# Created glyph image for derge_ཕྲུ_15.png
# Created glyph image for derge_ཧྲ_52.png
# Created glyph image for derge_པོ_28.png
# Created glyph image for derge_ལྡུ_3.png
# Created glyph image for derge_གྱ_2.png
# Created glyph image for derge_ཕྲུ_17.png
# Created glyph image for derge_ལྗ_19.png
# Created glyph image for derge_སྒ_30.png
# Created glyph image for derge_ཧྲ_46.png
# Created glyph image for derge_སྤྲུ_26.png
# Created glyph image for derge_ཇུ_21.png
# Created glyph image for derge_ཎྜ_16.png
# Created glyph image for derge_སྥཱུ.png
# Created glyph image for derge_རྒྱུ_34.png
# Created glyph image for derge_རེ_18.png
# Created glyph image for derge_སྭ_63.png
# Created glyph image for derge_ཥྐྲ.png
# Created glyph image for derge_རྤ.png
# Created glyph image for derge_དྨ_13.png
# Created glyph image for derge_ཎྱ_25.png
# Created glyph image for derge_རུ_21.png
# Created glyph image for derge_ནྡྲ_75.png
# Created glyph image for derge_སྤུ_2.png
# Created glyph image for derge_ཙྪ_10.png
# Created glyph image for derge_ཇེ_18.png
# Created glyph image for derge_ཙ_10.png
# Created glyph image for derge_ཀྲུ_10.png
# Created glyph image for derge_ཏྠུ.png
# Created glyph image for derge_ཅི_19.png
# Created glyph image for derge_ཁྲུ_10.png
# Created glyph image for derge_བུ_15.png
# Created glyph image for derge_འི_19.png
# Created glyph image for derge_སྙུ_97.png
# Created glyph image for derge_བེ_10.png
# Created glyph image for derge_ཥྚ_5.png
# Created glyph image for derge_ཡཱུ_8.png
# Created glyph image for derge_སླ_100.png
# Created glyph image for derge_སྟུ_11.png
# Created glyph image for derge_ནྱ_100.png
# Created glyph image for derge_འི_25.png
# Created glyph image for derge_སྨཱ_61.png
# Created glyph image for derge_གྒ_21.png
# Created glyph image for derge_མི_23.png
# Created glyph image for derge_ཎཱ_12.png
# Created glyph image for derge_ྔ_2.png
# Created glyph image for derge_རྐ_15.png
# Created glyph image for derge_༑_1.png
# Created glyph image for derge_རྦྷུ.png
# Created glyph image for derge_རྙ_25.png
# Created glyph image for derge_ལྟུ_27.png
# Created glyph image for derge_྅_81.png
# Created glyph image for derge_པྲ_26.png
# Created glyph image for derge_རྗ_20.png
# Created glyph image for derge_མྱུ_11.png
# Created glyph image for derge_གྱ_17.png
# Created glyph image for derge_ངྐ_1.png
# Created glyph image for derge_ཟོ_1.png
# Created glyph image for derge_པྟ_15.png
# Created glyph image for derge_ཎྜཱ_67.png
# Created glyph image for derge_རྙ_19.png
# Created glyph image for derge_སྩ_13.png
# Created glyph image for derge_ལྷ_42.png
# Created glyph image for derge_རྒུ_10.png
# Created glyph image for derge_དྦྷཱུ.png
# Created glyph image for derge_བླ_17.png
# Created glyph image for derge_ཉོ_12.png
# Created glyph image for derge_ྭ_2.png
# Created glyph image for derge_ནྟ_2.png
# Created glyph image for derge_ཥ_12.png
# Created glyph image for derge_ཁ_11.png
# Created glyph image for derge_ངྒ_64.png
# Created glyph image for derge_ཀླུ_15.png
# Created glyph image for derge_རྫུ_13.png
# Created glyph image for derge_ༀ_33.png
# Created glyph image for derge_བི_2.png
# Created glyph image for derge_རྦུ_24.png
# Created glyph image for derge_ཏ_14.png
# Created glyph image for derge_དྷཱ_20.png
# Created glyph image for derge_ཉི_17.png
# Created glyph image for derge_ཎྜྷཱ.png
# Created glyph image for derge_འེ_82.png
# Created glyph image for derge_སྦྱ_15.png
# Created glyph image for derge_སེ_10.png
# Created glyph image for derge_སྦ_100.png
# Created glyph image for derge_ཎྱཱ_49.png
# Created glyph image for derge_ཏྐ_8.png
# Created glyph image for derge_ྲ_6.png
# Created glyph image for derge_གླ_12.png
# Created glyph image for derge_སྒྲུ_10.png
# Created glyph image for derge_ཚཱུ.png
# Created glyph image for derge_བེ_100.png
# Created glyph image for derge_རྭ_43.png
# Created glyph image for derge_རཱུ_11.png
# Created glyph image for derge_སུ_15.png
# Created glyph image for derge_ཐི_19.png
# Created glyph image for derge_མླ.png
# Created glyph image for derge_དྷཱུ_29.png
# Created glyph image for derge_ཧྞ_35.png
# Created glyph image for derge_བྷཱུ_65.png
# Created glyph image for derge_ཛྱ_25.png
# Created glyph image for derge_ཤོ_14.png
# Created glyph image for derge_དྲུ_100.png
# Created glyph image for derge_བྱ_12.png
# Created glyph image for derge_ཁོ_14.png
# Created glyph image for derge_ཧ_17.png
# Created glyph image for derge_ྫ_4.png
# Created glyph image for derge_ཟུ_16.png
# Created glyph image for derge_མཱུ_55.png
# Created glyph image for derge_སླུ_12.png
# Created glyph image for derge_ཁི_11.png
# Created glyph image for derge_ཏྟཱ_13.png
# Created glyph image for derge_ཁྭ_12.png
# Created glyph image for derge_ཚི_2.png
# Created glyph image for derge_ཊ_18.png
# Created glyph image for derge_ཚཱ_17.png
# Created glyph image for derge_མུ_1.png
# Created glyph image for derge_ཤི_11.png
# Created glyph image for derge_ཤྭ_12.png
# Created glyph image for derge_རྟུ_1.png
# Created glyph image for derge_ཏེ_22.png
# Created glyph image for derge_རླུ_18.png
# Created glyph image for derge_ཊཱ_32.png
# Created glyph image for derge_བྱུ_18.png
# Created glyph image for derge_ཧེ_15.png
# Created glyph image for derge_མྱུ_100.png
# Created glyph image for derge_བླ_1.png
# Created glyph image for derge_སླ_17.png
# Created glyph image for derge_རྒྱ_17.png
# Created glyph image for derge_ཧུ_10.png
# Created glyph image for derge_ཌྷ_1.png
# Created glyph image for derge_གུ_10.png
# Created glyph image for derge_ཎྱ_2.png
# Created glyph image for derge_ལྱ_23.png
# Created glyph image for derge_ཨོ_32.png
# Created glyph image for derge_ཀོ_11.png
# Created glyph image for derge_ཛ_15.png
# Created glyph image for derge_ྞ_9.png
# Created glyph image for derge_ཞུ_13.png
# Created glyph image for derge_དྷཱིཿ_45.png
# Created glyph image for derge_ྩ_6.png
# Created glyph image for derge_ཛྱཱ_4.png
# Created glyph image for derge_ཨོ_26.png
# Created glyph image for derge_ནུ_18.png
# Created glyph image for derge_ཨི_23.png
# Created glyph image for derge_ཥྛ_48.png
# Created glyph image for derge_ཟླ_28.png
# Created glyph image for derge_ཧཱུ_33.png
# Created glyph image for derge_དྷཱིཿ_79.png
# Created glyph image for derge_ཙྪཱུ.png
# Created glyph image for derge_ཕ_10.png
# Created glyph image for derge_ཁཱ_68.png
# Created glyph image for derge_ཕ_1.png
# Created glyph image for derge_ཞེ_16.png
# Created glyph image for derge_སྲུ_17.png
# Created glyph image for derge_ཀི_14.png
# Created glyph image for derge_སྲུ_16.png
# Created glyph image for derge_ཌྷ.png
# Created glyph image for derge_ཕ_11.png
# Created glyph image for derge_ཧཱུ_32.png
# Created glyph image for derge_ནེ_20.png
# Created glyph image for derge_དྡྷ_17.png
# Created glyph image for derge_ཀི_15.png
# Created glyph image for derge_སཱུ_32.png
# Created glyph image for derge_ཀུ_1.png
# Created glyph image for derge_ངཱ_1.png
# Created glyph image for derge_ལྟ_1.png
# Created glyph image for derge_སྨྱ_4.png
# Created glyph image for derge_ཥྛ_49.png
# Created glyph image for derge_ྩ_7.png
# Created glyph image for derge_ཨོ_27.png
# Created glyph image for derge_ཤྲ_33.png
# Created glyph image for derge_སྟཱ_34.png
# Created glyph image for derge_ཀོ_10.png
# Created glyph image for derge_ཛ_14.png
# Created glyph image for derge_ཤྱཱ_29.png
# Created glyph image for derge_གུ_11.png
# Created glyph image for derge_ལྱ_22.png
# Created glyph image for derge_རྩ_26.png
# Created glyph image for derge_༈_95.png
# Created glyph image for derge_ཋ_100.png
# Created glyph image for derge_རྒྱ_16.png
# Created glyph image for derge_སླ_16.png
# Created glyph image for derge_ཧྣ_1.png
# Created glyph image for derge_རྠ_16.png
# Created glyph image for derge_གྫ.png
# Created glyph image for derge_ཀྣ.png
# Created glyph image for derge_དོ_18.png
# Created glyph image for derge_ཧེ_14.png
# Created glyph image for derge_སྙ_10.png
# Created glyph image for derge_གྷླཱ.png
# Created glyph image for derge_ཌ_2.png
# Created glyph image for derge_ོ_52.png
# Created glyph image for derge_མཱུ_40.png
# Created glyph image for derge_ཊ_19.png
# Created glyph image for derge_ཁྭ_13.png
# Created glyph image for derge_ཀྵ_17.png
# Created glyph image for derge_ཁོ_15.png
# Created glyph image for derge_ཟུ_17.png
# Created glyph image for derge_འེ_54.png
# Created glyph image for derge_ྫ_5.png
# Created glyph image for derge_ཟླུ_10.png
# Created glyph image for derge_ཧ_16.png
# Created glyph image for derge_ཤོ_15.png
# Created glyph image for derge_བྱ_13.png
# Created glyph image for derge_ཏྠཱ_40.png
# Created glyph image for derge_རྡྲ.png
# Created glyph image for derge_དྲ_16.png
# Created glyph image for derge_སུ_14.png
# Created glyph image for derge_ཎྱཱ_60.png
# Created glyph image for derge_ནྟུ_75.png
# Created glyph image for derge_ཧྞ_34.png
# Created glyph image for derge_རྩྭ_2.png
# Created glyph image for derge_ཐི_18.png
# Created glyph image for derge_སྒྲུ_11.png
# Created glyph image for derge_གླ_13.png
# Created glyph image for derge_ྲ_7.png
# Created glyph image for derge_མྥ.png
# Created glyph image for derge_ཙྱཱ.png
# Created glyph image for derge_རྒ_11.png
# Created glyph image for derge_ཏྐ_12.png
# Created glyph image for derge_སྦྱ_14.png
# Created glyph image for derge_ཉི_16.png
# Created glyph image for derge_ངྒ_59.png
# Created glyph image for derge_སྤྲ_34.png
# Created glyph image for derge_ངི_21.png
# Created glyph image for derge_གི_100.png
# Created glyph image for derge_དྷཱ_21.png
# Created glyph image for derge_ཏ_15.png
# Created glyph image for derge_ཀླུ_14.png
# Created glyph image for derge_རྫུ_12.png
# Created glyph image for derge_ཁ_10.png
# Created glyph image for derge_ཞ_100.png
# Created glyph image for derge_ཟོ_100.png
# Created glyph image for derge_དྲུ_20.png
# Created glyph image for derge_བླ_16.png
# Created glyph image for derge_ཉོ_13.png
# Created glyph image for derge_ྭ_3.png
# Created glyph image for derge_པྟ_14.png
# Created glyph image for derge_རྞ_11.png
# Created glyph image for derge_ྴ_1.png
# Created glyph image for derge_རྒུ_11.png
# Created glyph image for derge_ལྷུ_11.png
# Created glyph image for derge_སྩ_12.png
# Created glyph image for derge_ཎྜཱ_66.png
# Created glyph image for derge_རྗ_21.png
# Created glyph image for derge_སྐྲ_28.png
# Created glyph image for derge_྅_80.png
# Created glyph image for derge_གྱ_16.png
# Created glyph image for derge_ལེ_20.png
# Created glyph image for derge_རྩྭ_15.png
# Created glyph image for derge_རྙ_24.png
# Created glyph image for derge_སྐྱུ_22.png
# Created glyph image for derge_ཀྵ_2.png
# Created glyph image for derge_གླ_1.png
# Created glyph image for derge_ྔ_3.png
# Created glyph image for derge_རྐ_14.png
# Created glyph image for derge_དྷྱཱ.png
# Created glyph image for derge_སྨ_2.png
# Created glyph image for derge_འི_24.png
# Created glyph image for derge_སྟུ_10.png
# Created glyph image for derge_བེ_11.png
# Created glyph image for derge_བུ_14.png
# Created glyph image for derge_སྟྱཱ.png
# Created glyph image for derge_ཨུ_2.png
# Created glyph image for derge_འི_18.png
# Created glyph image for derge_ཀྲུ_11.png
# Created glyph image for derge_ཙ_11.png
# Created glyph image for derge_ཞ_18.png
# Created glyph image for derge_སྙུ_41.png
# Created glyph image for derge_ཎྱ_24.png
# Created glyph image for derge_དྦཱ.png
# Created glyph image for derge_ཇུ_34.png
# Created glyph image for derge_ཙྪ_11.png
# Created glyph image for derge_རྔ_2.png
# Created glyph image for derge_ལླཱ_29.png
# Created glyph image for derge_པོ_15.png
# Created glyph image for derge_ཎྜ_17.png
# Created glyph image for derge_ཙོ_22.png
# Created glyph image for derge_དྨ_12.png
# Created glyph image for derge_ལྗ_18.png
# Created glyph image for derge_ཏྣ_2.png
# Created glyph image for derge_སྤྲུ_27.png
# Created glyph image for derge_བྱཱ_15.png
# Created glyph image for derge_ཧྲ_47.png
# Created glyph image for derge_བྷྲཱུ.png
# Created glyph image for derge_སྤྲུ_33.png
# Created glyph image for derge_རྡྡྲ.png
# Created glyph image for derge_རྲ.png
# Created glyph image for derge_སྭ_66.png
# Created glyph image for derge_ཊུ_13.png
# Created glyph image for derge_དྨ_16.png
# Created glyph image for derge_ཙོ_26.png
# Created glyph image for derge_ངྒ_6.png
# Created glyph image for derge_ཧཱ_19.png
# Created glyph image for derge_ཎྜ_13.png
# Created glyph image for derge_ལླཱ_39.png
# Created glyph image for derge_པོ_11.png
# Created glyph image for derge_པི_28.png
# Created glyph image for derge_པྲཱ_2.png
# Created glyph image for derge_ཙྪ_15.png
# Created glyph image for derge_ཏྱཱ_4.png
# Created glyph image for derge_ཇུ_30.png
# Created glyph image for derge_ནྷྲ.png
# Created glyph image for derge_ཕྲ_26.png
# Created glyph image for derge_ཡྭ.png
# Created glyph image for derge_ཧྲུ_6.png
# Created glyph image for derge_སྒ_21.png
# Created glyph image for derge_ཇེ_21.png
# Created glyph image for derge_ཧཱ_31.png
# Created glyph image for derge_རྒྱུ_19.png
# Created glyph image for derge_ཧྲ_43.png
# Created glyph image for derge_ཕྲུ_12.png
# Created glyph image for derge_རུ_18.png
# Created glyph image for derge_ཅི_20.png
# Created glyph image for derge_བེ_15.png
# Created glyph image for derge_ཀྲུ_29.png
# Created glyph image for derge_ན_2.png
# Created glyph image for derge_ཙ_29.png
# Created glyph image for derge_སྨྲ_16.png
# Created glyph image for derge_སྨཱ_64.png
# Created glyph image for derge_སྙུ_86.png
# Created glyph image for derge_ཌྷ_18.png
# Created glyph image for derge_ཁྲུ_15.png
# Created glyph image for derge_ུ_26.png
# Created glyph image for derge_དྷྱ_12.png
# Created glyph image for derge_བུ_10.png
# Created glyph image for derge_མྱུ_14.png
# Created glyph image for derge_གྱ_12.png
# Created glyph image for derge_ཆེ_18.png
# Created glyph image for derge_ལྷུ_2.png
# Created glyph image for derge_ཏྱ_25.png
# Created glyph image for derge_྅_84.png
# Created glyph image for derge_པྲ_23.png
# Created glyph image for derge_྅_90.png
# Created glyph image for derge_ལེ_18.png
# Created glyph image for derge_རྒུ_15.png
# Created glyph image for derge_ཕོ_14.png
# Created glyph image for derge_རྞ_15.png
# Created glyph image for derge_དོ_1.png
# Created glyph image for derge_ཎཱ_17.png
# Created glyph image for derge_རྐ_10.png
# Created glyph image for derge_ྔ_7.png
# Created glyph image for derge_རྗ_19.png
# Created glyph image for derge_སྐྲ_10.png
# Created glyph image for derge_ཏྱ_19.png
# Created glyph image for derge_མི_26.png
# Created glyph image for derge_རྩྭ_11.png
# Created glyph image for derge_ྣ_8.png
# Created glyph image for derge_ནེ_2.png
# Created glyph image for derge_ཏ_11.png
# Created glyph image for derge_སྲ_100.png
# Created glyph image for derge_ཞྭ_4.png
# Created glyph image for derge_སྤྲ_24.png
# Created glyph image for derge_དྲུ_18.png
# Created glyph image for derge_ར_22.png
# Created glyph image for derge_ཚུ_1.png
# Created glyph image for derge_ཉི_12.png
# Created glyph image for derge_ཛྙ_23.png
# Created glyph image for derge_དཱུ_28.png
# Created glyph image for derge_ྭ_7.png
# Created glyph image for derge_བླ_12.png
# Created glyph image for derge_ༀ_36.png
# Created glyph image for derge_ཥ_17.png
# Created glyph image for derge_ཁ_14.png
# Created glyph image for derge_ྚ_8.png
# Created glyph image for derge_ཡོ_20.png
# Created glyph image for derge_ཀླུ_10.png
# Created glyph image for derge_ྲ_3.png
# Created glyph image for derge_ལྱཱ_7.png
# Created glyph image for derge_སྒྲུ_15.png
# Created glyph image for derge_རྐ_2.png
# Created glyph image for derge_ལྤ_7.png
# Created glyph image for derge_གྲྭ_24.png
# Created glyph image for derge_ཧྞ_30.png
# Created glyph image for derge_ཧཱུཾ_38.png
# Created glyph image for derge_ནྟུ_71.png
# Created glyph image for derge_ཏྟྱ.png
# Created glyph image for derge_སུ_10.png
# Created glyph image for derge_དྲ_12.png
# Created glyph image for derge_རཱུ_14.png
# Created glyph image for derge_སྦྱ_10.png
# Created glyph image for derge_སེ_15.png
# Created glyph image for derge_རྒ_15.png
# Created glyph image for derge_ཎྱཱ_58.png
# Created glyph image for derge_རཱུ_28.png
# Created glyph image for derge_ཝི_17.png
# Created glyph image for derge_ཀྵ_13.png
# Created glyph image for derge_ོ_42.png
# Created glyph image for derge_རྡྡ.png
# Created glyph image for derge_ཟླུ_28.png
# Created glyph image for derge_ཤི_14.png
# Created glyph image for derge_ཤྭ_17.png
# Created glyph image for derge_མཱུ_44.png
# Created glyph image for derge_མྨྲཱ.png
# Created glyph image for derge_ཀྟ_29.png
# Created glyph image for derge_ཁོ_100.png
# Created glyph image for derge_ཥཱ_40.png
# Created glyph image for derge_བྱ_17.png
# Created glyph image for derge_བུ_1.png
# Created glyph image for derge_ཤོ_11.png
# Created glyph image for derge_འེ_44.png
# Created glyph image for derge_ྫ_1.png
# Created glyph image for derge_ཧ_12.png
# Created glyph image for derge_ཛྙཱ_68.png
# Created glyph image for derge_རྩཱ.png
# Created glyph image for derge_ཀོ_100.png
# Created glyph image for derge_ཎཱུ_10.png
# Created glyph image for derge_ཁོ_11.png
# Created glyph image for derge_ང_18.png
# Created glyph image for derge_ཁྴ.png
# Created glyph image for derge_རླུ_21.png
# Created glyph image for derge_རྠ_12.png
# Created glyph image for derge_ཧྣ_5.png
# Created glyph image for derge_སླ_12.png
# Created glyph image for derge_རྒྱ_12.png
# Created glyph image for derge_ཌྷ_4.png
# Created glyph image for derge_རྩ_22.png
# Created glyph image for derge_གེ_10.png
# Created glyph image for derge_དྭ_26.png
# Created glyph image for derge_ཀྱ_2.png
# Created glyph image for derge_གྷྲཱ.png
# Created glyph image for derge_གྷ_1.png
# Created glyph image for derge_སྙ_14.png
# Created glyph image for derge_ཏྲྱཱ.png
# Created glyph image for derge_ཧེ_10.png
# Created glyph image for derge_སཱུ_22.png
# Created glyph image for derge_ཀྭ_12.png
# Created glyph image for derge_དྡྷ_13.png
# Created glyph image for derge_ཀི_11.png
# Created glyph image for derge_ཕ_15.png
# Created glyph image for derge_སྲུ_12.png
# Created glyph image for derge_ཚྭ_68.png
# Created glyph image for derge_ཉྫུ_9.png
# Created glyph image for derge_ཛ_10.png
# Created glyph image for derge_ཞུ_16.png
# Created glyph image for derge_སྟཱ_24.png
# Created glyph image for derge_ཥྛ_65.png
# Created glyph image for derge_ྩ_3.png
# Created glyph image for derge_ཎུ_1.png
# Created glyph image for derge_ནེ_19.png
# Created glyph image for derge_ཤྲ_36.png
# Created glyph image for derge_ཊཱ_1.png
# Created glyph image for derge_ྩ_2.png
# Created glyph image for derge_ཛ_11.png
# Created glyph image for derge_རྒྷྱ.png
# Created glyph image for derge_ཀི_10.png
# Created glyph image for derge_དྡྷ_12.png
# Created glyph image for derge_སཱུ_23.png
# Created glyph image for derge_ཚྭ_69.png
# Created glyph image for derge_སྲུ_13.png
# Created glyph image for derge_ཞེ_12.png
# Created glyph image for derge_ཉྟ.png
# Created glyph image for derge_ཌྲ.png
# Created glyph image for derge_བྲུ_2.png
# Created glyph image for derge_ཕ_14.png
# Created glyph image for derge_ལྔུ.png
# Created glyph image for derge_ཎྭ.png
# Created glyph image for derge_ཧེ_11.png
# Created glyph image for derge_དྭ_33.png
# Created glyph image for derge_དྭ_27.png
# Created glyph image for derge_གེ_11.png
# Created glyph image for derge_སྨུ_6.png
# Created glyph image for derge_ཊཱ_22.png
# Created glyph image for derge_སྣུ_27.png
# Created glyph image for derge_བྱུ_20.png
# Created glyph image for derge_རྩ_23.png
# Created glyph image for derge_རྒྲཱ.png
# Created glyph image for derge_ལེ_1.png
# Created glyph image for derge_ཏྱཱུ.png
# Created glyph image for derge_དི_18.png
# Created glyph image for derge_ཅོ_1.png
# Created glyph image for derge_རླུ_20.png
# Created glyph image for derge_ལྦ_4.png
# Created glyph image for derge_ཌྷ_5.png
# Created glyph image for derge_རྒྱ_13.png
# Created glyph image for derge_སླ_13.png
# Created glyph image for derge_ཧྣ_4.png
# Created glyph image for derge_ཛྙཱ_69.png
# Created glyph image for derge_ཛྱ_35.png
# Created glyph image for derge_ཧ_13.png
# Created glyph image for derge_པྣ.png
# Created glyph image for derge_ཁོ_10.png
# Created glyph image for derge_ཥཱ_41.png
# Created glyph image for derge_བྱ_16.png
# Created glyph image for derge_རྡྷ.png
# Created glyph image for derge_ཤོ_10.png
# Created glyph image for derge_འེ_45.png
# Created glyph image for derge_ཤི_15.png
# Created glyph image for derge_ངྐུ_8.png
# Created glyph image for derge_སུ_100.png
# Created glyph image for derge_ཀྟ_28.png
# Created glyph image for derge_ཏཱུ_39.png
# Created glyph image for derge_ཛྫཱ_18.png
# Created glyph image for derge_ོ_43.png
# Created glyph image for derge_གྠྱ.png
# Created glyph image for derge_ཀྵ_12.png
# Created glyph image for derge_ཟེ_17.png
# Created glyph image for derge_མཱུ_51.png
# Created glyph image for derge_ཧུ_100.png
# Created glyph image for derge_མྠ.png
# Created glyph image for derge_ཙྱུ.png
# Created glyph image for derge_མྱ_2.png
# Created glyph image for derge_རཱུ_29.png
# Created glyph image for derge_སེ_14.png
# Created glyph image for derge_ཀླ_1.png
# Created glyph image for derge_སྦྱ_11.png
# Created glyph image for derge_སྐྲུ_84.png
# Created glyph image for derge_རཱུ_15.png
# Created glyph image for derge_དྲ_13.png
# Created glyph image for derge_སུ_11.png
# Created glyph image for derge_ཊ_100.png
# Created glyph image for derge_རྭ_47.png
# Created glyph image for derge_རྤཱུ.png
# Created glyph image for derge_ནྟུ_70.png
# Created glyph image for derge_ཙླ.png
# Created glyph image for derge_སྒྲུ_14.png
# Created glyph image for derge_གླ_16.png
# Created glyph image for derge_ལཱུ_15.png
# Created glyph image for derge_ྲ_2.png
# Created glyph image for derge_རྒ_28.png
# Created glyph image for derge_ༀ_37.png
# Created glyph image for derge_ཀླུ_11.png
# Created glyph image for derge_རྫུ_17.png
# Created glyph image for derge_ཡོ_21.png
# Created glyph image for derge_ཁ_15.png
# Created glyph image for derge_དྷཱ_18.png
# Created glyph image for derge_ཡི_18.png
# Created glyph image for derge_ྭ_6.png
# Created glyph image for derge_ཉོ_16.png
# Created glyph image for derge_ཅཱུ.png
# Created glyph image for derge_ར_23.png
# Created glyph image for derge_དྲུ_19.png
# Created glyph image for derge_དྲཱ.png
# Created glyph image for derge_དཱུ_29.png
# Created glyph image for derge_ཉི_13.png
# Created glyph image for derge_༈_7.png
# Created glyph image for derge_ད_1.png
# Created glyph image for derge_ཞྭ_5.png
# Created glyph image for derge_ཏ_10.png
# Created glyph image for derge_རྙ_21.png
# Created glyph image for derge_ལྷུ_28.png
# Created glyph image for derge_མྤ_14.png
# Created glyph image for derge_སྲུ_2.png
# Created glyph image for derge_ྣ_9.png
# Created glyph image for derge_ཕུ_100.png
# Created glyph image for derge_དྷྱུ.png
# Created glyph image for derge_རྐ_11.png
# Created glyph image for derge_ྔ_6.png
# Created glyph image for derge_ཎཱ_16.png
# Created glyph image for derge_ཏྱ_18.png
# Created glyph image for derge_སྐྱུ_33.png
# Created glyph image for derge_པུ_100.png
# Created glyph image for derge_སྐྲ_11.png
# Created glyph image for derge_རྗ_18.png
# Created glyph image for derge_རྒུ_14.png
# Created glyph image for derge_སྩ_17.png
# Created glyph image for derge_ལེ_19.png
# Created glyph image for derge_ཉེ_100.png
# Created glyph image for derge_྅_91.png
# Created glyph image for derge_ཕོ_15.png
# Created glyph image for derge_ཆེ_19.png
# Created glyph image for derge_གྱ_13.png
# Created glyph image for derge_ཨ_1.png
# Created glyph image for derge_མྱུ_15.png
# Created glyph image for derge_རྞྞཱ.png
# Created glyph image for derge_བྷྲཱ.png
# Created glyph image for derge_྅_85.png
# Created glyph image for derge_ལྟུ_23.png
# Created glyph image for derge_ལྷུ_3.png
# Created glyph image for derge_ཏྟྭཱ.png
# Created glyph image for derge_བུ_11.png
# Created glyph image for derge_དྷྱ_13.png
# Created glyph image for derge_ཁྲུ_14.png
# Created glyph image for derge_ཊྷྱ.png
# Created glyph image for derge_མྣཱ.png
# Created glyph image for derge_ཀྲུ_14.png
# Created glyph image for derge_སྩུ.png
# Created glyph image for derge_སྨཱ_65.png
# Created glyph image for derge_འི_21.png
# Created glyph image for derge_སྨྲ_17.png
# Created glyph image for derge_ཐ_18.png
# Created glyph image for derge_སྒུ_36.png
# Created glyph image for derge_གུ_1.png
# Created glyph image for derge_བེ_14.png
# Created glyph image for derge_ཞ_21.png
# Created glyph image for derge_ཙ_28.png
# Created glyph image for derge_འོ_18.png
# Created glyph image for derge_ཀྲུ_28.png
# Created glyph image for derge_གྡྷཱ.png
# Created glyph image for derge_ཉོ_1.png
# Created glyph image for derge_སྦྱུ.png
# Created glyph image for derge_པྤ_26.png
# Created glyph image for derge_དྦུ.png
# Created glyph image for derge_ཇུ_31.png
# Created glyph image for derge_ཏྱཱ_5.png
# Created glyph image for derge_རྨྨྱ.png
# Created glyph image for derge_ནྡྲ_71.png
# Created glyph image for derge_པྲཱ_3.png
# Created glyph image for derge_ཕྲ_27.png
# Created glyph image for derge_གཱ_18.png
# Created glyph image for derge_དྨ_17.png
# Created glyph image for derge_ཙོ_27.png
# Created glyph image for derge_པོ_10.png
# Created glyph image for derge_རྒྱུ_30.png
# Created glyph image for derge_ཏྠ_15.png
# Created glyph image for derge_ཎྜ_12.png
# Created glyph image for derge_ཇུ_25.png
# Created glyph image for derge_ངྒ_7.png
# Created glyph image for derge_ཟི_98.png
# Created glyph image for derge_ཎྱ_23.png
# Created glyph image for derge_སྠཱ_4.png
# Created glyph image for derge_སྭ_71.png
# Created glyph image for derge_ནྡྲ_73.png
# Created glyph image for derge_ཙྪ_16.png
# Created glyph image for derge_ཏྱཱ_7.png
# Created glyph image for derge_ཎྜ_10.png
# Created glyph image for derge_རྒྱུ_32.png
# Created glyph image for derge_རྟཱ.png
# Created glyph image for derge_ཙོ_25.png
# Created glyph image for derge_དྨ_15.png
# Created glyph image for derge_ཊུ_38.png
# Created glyph image for derge_ཕྲ_19.png
# Created glyph image for derge_ྡ_9.png
# Created glyph image for derge_སྒ_22.png
# Created glyph image for derge_སྭ_59.png
# Created glyph image for derge_སྨྲ_15.png
# Created glyph image for derge_སྟུ_17.png
# Created glyph image for derge_ཛུ_18.png
# Created glyph image for derge_འི_23.png
# Created glyph image for derge_ན_1.png
# Created glyph image for derge_ཛེ_21.png
# Created glyph image for derge_བེ_16.png
# Created glyph image for derge_ཥྚ_3.png
# Created glyph image for derge_ཛྟཱ.png
# Created glyph image for derge_ུ_25.png
# Created glyph image for derge_ཁྲུ_16.png
# Created glyph image for derge_དྷྱ_11.png
# Created glyph image for derge_བུ_13.png
# Created glyph image for derge_སྨྲ_29.png
# Created glyph image for derge_ཀྲུ_16.png
# Created glyph image for derge_ཞཱ_19.png
# Created glyph image for derge_གྒུ.png
# Created glyph image for derge_ཕོ_17.png
# Created glyph image for derge_རྞ_16.png
# Created glyph image for derge_ལྷུ_16.png
# Created glyph image for derge_྅_87.png
# Created glyph image for derge_མྱུ_17.png
# Created glyph image for derge_གྱ_11.png
# Created glyph image for derge_ངྒཱ_21.png
# Created glyph image for derge_ནེ_1.png
# Created glyph image for derge_ཎྛཱ_4.png
# Created glyph image for derge_མྦུ_72.png
# Created glyph image for derge_ཀྟཱ.png
# Created glyph image for derge_རྙ_23.png
# Created glyph image for derge_རྩྭ_12.png
# Created glyph image for derge_ཀྵླཱ.png
# Created glyph image for derge_ཧྱ_39.png
# Created glyph image for derge_མི_25.png
# Created glyph image for derge_ཎཱ_14.png
# Created glyph image for derge_ྔ_4.png
# Created glyph image for derge_རྐ_13.png
# Created glyph image for derge_ར_21.png
# Created glyph image for derge_སྤྲ_33.png
# Created glyph image for derge_མི_1.png
# Created glyph image for derge_ཏྲཱ_13.png
# Created glyph image for derge_ཏྲྻ.png
# Created glyph image for derge_ཥ_14.png
# Created glyph image for derge_ཚེ_18.png
# Created glyph image for derge_ཁ_17.png
# Created glyph image for derge_ཀླུ_13.png
# Created glyph image for derge_རྫུ_15.png
# Created glyph image for derge_ༀ_35.png
# Created glyph image for derge_རྦུ_22.png
# Created glyph image for derge_བླ_11.png
# Created glyph image for derge_སྨྱུ_1.png
# Created glyph image for derge_ཉོ_14.png
# Created glyph image for derge_ྭ_4.png
# Created glyph image for derge_ནྜ_16.png
# Created glyph image for derge_ནྟུ_72.png
# Created glyph image for derge_ཏྟྲ.png
# Created glyph image for derge_སུ_13.png
# Created glyph image for derge_དྲ_11.png
# Created glyph image for derge_ཧྞ_33.png
# Created glyph image for derge_ལཱུ_17.png
# Created glyph image for derge_གླ_14.png
# Created glyph image for derge_ཙྱ.png
# Created glyph image for derge_ལྤ_4.png
# Created glyph image for derge_གྲྭ_27.png
# Created glyph image for derge_ཚྪ.png
# Created glyph image for derge_རྱ_20.png
# Created glyph image for derge_ནྟུ_66.png
# Created glyph image for derge_ལྟུ_2.png
# Created glyph image for derge_ཝི_14.png
# Created glyph image for derge_སྐྲུ_92.png
# Created glyph image for derge_འེ_90.png
# Created glyph image for derge_རྒ_16.png
# Created glyph image for derge_ཧྨ_44.png
# Created glyph image for derge_སྦྱ_13.png
# Created glyph image for derge_སེ_16.png
# Created glyph image for derge_གླུ_100.png
# Created glyph image for derge_ཤི_17.png
# Created glyph image for derge_མཱུ_47.png
# Created glyph image for derge_གྲུ_100.png
# Created glyph image for derge_རྩ_1.png
# Created glyph image for derge_ཟེ_15.png
# Created glyph image for derge_སླུ_14.png
# Created glyph image for derge_ཀྲ_19.png
# Created glyph image for derge_སྐྲུ_79.png
# Created glyph image for derge_ནྡུ_5.png
# Created glyph image for derge_ཀྵ_10.png
# Created glyph image for derge_ཁོ_12.png
# Created glyph image for derge_རྠྱ.png
# Created glyph image for derge_ྫ_2.png
# Created glyph image for derge_ཟླུ_17.png
# Created glyph image for derge_ཧ_11.png
# Created glyph image for derge_འེ_53.png
# Created glyph image for derge_ཤི_100.png
# Created glyph image for derge_ཟུ_10.png
# Created glyph image for derge_བྷཱུ_63.png
# Created glyph image for derge_བྱ_14.png
# Created glyph image for derge_སྦུ_1.png
# Created glyph image for derge_དོ_23.png
# Created glyph image for derge_རྩ_21.png
# Created glyph image for derge_བྱུ_22.png
# Created glyph image for derge_ཧྣ_6.png
# Created glyph image for derge_྅_100.png
# Created glyph image for derge_ཧུ_16.png
# Created glyph image for derge_ཁྷ.png
# Created glyph image for derge_དྭ_31.png
# Created glyph image for derge_ཀྱ_1.png
# Created glyph image for derge_བྷུ_98.png
# Created glyph image for derge_དྭ_25.png
# Created glyph image for derge_སྲུ_11.png
# Created glyph image for derge_ཞེ_10.png
# Created glyph image for derge_དྡྷ_10.png
# Created glyph image for derge_༈_51.png
# Created glyph image for derge_ཨི_25.png
# Created glyph image for derge_ཤྱཱ_12.png
# Created glyph image for derge_རྱུ.png
# Created glyph image for derge_ཊཱ_3.png
# Created glyph image for derge_ཤྲ_34.png
# Created glyph image for derge_གྱུ_19.png
# Created glyph image for derge_ཀོ_17.png
# Created glyph image for derge_ཨོ_34.png
# Created glyph image for derge_ཤཱུ_3.png
# Created glyph image for derge_ཛ_13.png
# Created glyph image for derge_ཟླ_12.png
# Created glyph image for derge_ཤཱུ_2.png
# Created glyph image for derge_ཟླ_13.png
# Created glyph image for derge_ཛ_12.png
# Created glyph image for derge_ྩ_1.png
# Created glyph image for derge_དྷཱིཿ_42.png
# Created glyph image for derge_ཤྲ_35.png
# Created glyph image for derge_ཛྱཱ_3.png
# Created glyph image for derge_གྱུ_18.png
# Created glyph image for derge_ཨི_24.png
# Created glyph image for derge_སཱུ_34.png
# Created glyph image for derge_ཧྲུ_10.png
# Created glyph image for derge_ངྷ_20.png
# Created glyph image for derge_ཞེ_11.png
# Created glyph image for derge_ཌྱ.png
# Created glyph image for derge_བྲུ_1.png
# Created glyph image for derge_ཧཱུ_34.png
# Created glyph image for derge_ཕ_17.png
# Created glyph image for derge_ཀི_13.png
# Created glyph image for derge_དྡྷ_11.png
# Created glyph image for derge_ནྡྷུ_7.png
# Created glyph image for derge_རྵྱ.png
# Created glyph image for derge_སྣུ_24.png
# Created glyph image for derge_བྷུ_99.png
# Created glyph image for derge_ཊཱ_21.png
# Created glyph image for derge_ཙྩཱ.png
# Created glyph image for derge_དྭ_30.png
# Created glyph image for derge_ཧེ_12.png
# Created glyph image for derge_སྙ_16.png
# Created glyph image for derge_ཌྷ_6.png
# Created glyph image for derge_སླ_10.png
# Created glyph image for derge_རྒྱ_10.png
# Created glyph image for derge_ཧྣ_7.png
# Created glyph image for derge_གྭ.png
# Created glyph image for derge_རྒ_2.png
# Created glyph image for derge_ཡོ_1.png
# Created glyph image for derge_ལེ_2.png
# Created glyph image for derge_གུ_17.png
# Created glyph image for derge_ཉཱ.png
# Created glyph image for derge_བྱུ_23.png
# Created glyph image for derge_ཤོ_13.png
# Created glyph image for derge_བྟྱ.png
# Created glyph image for derge_བྱ_15.png
# Created glyph image for derge_བ_100.png
# Created glyph image for derge_དྐུ.png
# Created glyph image for derge_ཁོ_13.png
# Created glyph image for derge_ཟུ_11.png
# Created glyph image for derge_བྷཱུ_76.png
# Created glyph image for derge_པྠ.png
# Created glyph image for derge_ཧ_10.png
# Created glyph image for derge_ྜ_10.png
# Created glyph image for derge_ྫ_3.png
# Created glyph image for derge_སྐྲུ_78.png
# Created glyph image for derge_སླུ_15.png
# Created glyph image for derge_ཟེ_14.png
# Created glyph image for derge_ཁྭ_15.png
# Created glyph image for derge_ོ_40.png
# Created glyph image for derge_སྒྲ_3.png
# Created glyph image for derge_ཀྵ_11.png
# Created glyph image for derge_ཝུ.png
# Created glyph image for derge_གེ_100.png
# Created glyph image for derge_མཱུ_46.png
# Created glyph image for derge_ཤི_16.png
# Created glyph image for derge_རྒ_17.png
# Created glyph image for derge_ཧྨ_45.png
# Created glyph image for derge_ཏྐ_14.png
# Created glyph image for derge_སེ_17.png
# Created glyph image for derge_ཀླ_2.png
# Created glyph image for derge_རྞྞ_4.png
# Created glyph image for derge_ལྟུ_3.png
# Created glyph image for derge_གྲྭ_26.png
# Created glyph image for derge_ལྤ_5.png
# Created glyph image for derge_གླ_15.png
# Created glyph image for derge_ྲ_1.png
# Created glyph image for derge_ནྟུ_67.png
# Created glyph image for derge_རཱུ_16.png
# Created glyph image for derge_དྲ_10.png
# Created glyph image for derge_སུ_12.png
# Created glyph image for derge_བླ_10.png
# Created glyph image for derge_ཉོ_15.png
# Created glyph image for derge_ྭ_5.png
# Created glyph image for derge_ཀླུ_12.png
# Created glyph image for derge_རྫུ_14.png
# Created glyph image for derge_རྦྦ_2.png
# Created glyph image for derge_ཁ_16.png
# Created glyph image for derge_ཚེ_19.png
# Created glyph image for derge_ཤྨཱ.png
# Created glyph image for derge_ཥ_15.png
# Created glyph image for derge_ༀ_34.png
# Created glyph image for derge_དྷཱ_27.png
# Created glyph image for derge_རྡྡྷཱ.png
# Created glyph image for derge_ཉི_10.png
# Created glyph image for derge_ར_20.png
# Created glyph image for derge_མི_24.png
# Created glyph image for derge_ཧྱ_38.png
# Created glyph image for derge_ྔ_5.png
# Created glyph image for derge_རྐ_12.png
# Created glyph image for derge_ཎཱ_15.png
# Created glyph image for derge_སྲུ_1.png
# Created glyph image for derge_རྩྭ_13.png
# Created glyph image for derge_རྡུ_1.png
# Created glyph image for derge_྅_86.png
# Created glyph image for derge_ལྷ_51.png
# Created glyph image for derge_ངྒཱ_20.png
# Created glyph image for derge_པྟ_12.png
# Created glyph image for derge_ཕོ_16.png
# Created glyph image for derge_རྒུ_17.png
# Created glyph image for derge_སྩ_14.png
# Created glyph image for derge_སྦྱ_100.png
# Created glyph image for derge_྅_92.png
# Created glyph image for derge_དྷྲ.png
# Created glyph image for derge_བུ_12.png
# Created glyph image for derge_རྣ_100.png
# Created glyph image for derge_ཁྲུ_17.png
# Created glyph image for derge_ུ_24.png
# Created glyph image for derge_ཛེ_20.png
# Created glyph image for derge_ཋ_77.png
# Created glyph image for derge_སུ_1.png
# Created glyph image for derge_གུ_2.png
# Created glyph image for derge_བེ_17.png
# Created glyph image for derge_སྙུ_84.png
# Created glyph image for derge_འི_22.png
# Created glyph image for derge_རྴ_6.png
# Created glyph image for derge_སྥུ.png
# Created glyph image for derge_སྒ_23.png
# Created glyph image for derge_དྷཱ_100.png
# Created glyph image for derge_ཕྲ_18.png
# Created glyph image for derge_དྷྭ_4.png
# Created glyph image for derge_ཏཱ_10.png
# Created glyph image for derge_པོ_13.png
# Created glyph image for derge_རྒྱུ_33.png
# Created glyph image for derge_ངྒ_4.png
# Created glyph image for derge_དྨ_14.png
# Created glyph image for derge_ཤྕ.png
# Created glyph image for derge_ཊུ_11.png
# Created glyph image for derge_ས_100.png
# Created glyph image for derge_པླ_3.png
# Created glyph image for derge_སྭ_64.png
# Created glyph image for derge_ཏྱཱ_6.png
# Created glyph image for derge_ཝུ_13.png
# Created glyph image for derge_ཀཾ_100.png
# Created glyph image for derge_ཀཱུ_97.png
# Created glyph image for derge_ྦ_9.png
# Created glyph image for derge_ཏྠ_59.png
# Created glyph image for derge_མྲ_48.png
# Created glyph image for derge_ཉྫུ_12.png
# Created glyph image for derge_སྐྱ_18.png
# Created glyph image for derge_རྡུ_10.png
# Created glyph image for derge_པྱ_17.png
# Created glyph image for derge_ཏྲ_11.png
# Created glyph image for derge_ཀཱུ_83.png
# Created glyph image for derge_སོ_11.png
# Created glyph image for derge_སྣ_12.png
# Created glyph image for derge_ནྣ_6.png
# Created glyph image for derge_རྫ_42.png
# Created glyph image for derge_སི_14.png
# Created glyph image for derge_སྒུ_85.png
# Created glyph image for derge_སྱ_66.png
# Created glyph image for derge_ྱ_4.png
# Created glyph image for derge_ཐུ_18.png
# Created glyph image for derge_སྐྱ_24.png
# Created glyph image for derge_ཊྚ_23.png
# Created glyph image for derge_དྡུ.png
# Created glyph image for derge_མྲ_60.png
# Created glyph image for derge_སྱ_72.png
# Created glyph image for derge_ཤྤ.png
# Created glyph image for derge_བྷཱ_25.png
# Created glyph image for derge_ྟ_9.png
# Created glyph image for derge_མྤཱ.png
# Created glyph image for derge_ཁུ_38.png
# Created glyph image for derge_ཁེ_15.png
# Created glyph image for derge_།_13.png
# Created glyph image for derge_སྦྲུ_29.png
# Created glyph image for derge_ཅ_15.png
# Created glyph image for derge_ཀྐ_21.png
# Created glyph image for derge_ཀཱུ.png
# Created glyph image for derge_ཏྦུ.png
# Created glyph image for derge_ྨ_6.png
# Created glyph image for derge_ཨོཾ_18.png
# Created glyph image for derge_སྒྱ_6.png
# Created glyph image for derge_རྦྷཱུ.png
# ...
# Created glyph image for derge_ྜ_6.png
# Created glyph image for derge_བྟ_3.png
# Created glyph image for derge_ཁྭ_23.png
# Created glyph image for derge_ཥཱ_48.png
# Created glyph image for derge_ནྟུ_86.png
# Created glyph image for derge_ཏྟཱ_36.png
# Created glyph image for derge_འ_13.png
# Created glyph image for derge_ང_10.png
# Created glyph image for derge_ྫ_9.png
# Created glyph image for derge_༅_32.png
# Created glyph image for derge_བྷཱུ_97.png
# Created glyph image for derge_ཛྫཱ.png
# Created glyph image for derge_ཝི_23.png
# Created glyph image for derge_མྦ_6.png
# Created glyph image for derge_ཐི_14.png
# Created glyph image for derge_ཧྞ_38.png
# Created glyph image for derge_ཙྲཱ.png
# Created glyph image for derge_ཐོ_11.png
# Created glyph image for derge_གྲྭ_10.png
# Created glyph image for derge_སྦྱ_18.png
# Created glyph image for derge_བོ_97.png
# Created glyph image for derge_ཏྐ_5.png
# Created glyph image for derge_སྒྲུ_35.png
# Created glyph image for derge_དྷཱུ_18.png
# Created glyph image for derge_ླ_10.png
# Created glyph image for derge_ངོ_14.png
# Created glyph image for derge_ཚུ_16.png
# Created glyph image for derge_ངྒུ_4.png
# Created glyph image for derge_ཡོ_14.png
# Created glyph image for derge_ངྒ_55.png
# Created glyph image for derge_ཏྲཱ_24.png
# Created glyph image for derge_སྤྲ_10.png
# Created glyph image for derge_གྱ_100.png
# Created glyph image for derge_ཡི_11.png
# Created glyph image for derge_ཀླུ_18.png
# Created glyph image for derge_ར_16.png
# Created glyph image for derge_ངི_11.png
# Created glyph image for derge_ཏྲཱ_30.png
# Created glyph image for derge_ཆ_15.png
# Created glyph image for derge_མི_12.png
# Created glyph image for derge_སྐྲ_24.png
# Created glyph image for derge_ཆེ_10.png
# Created glyph image for derge_ཎཱ_23.png
# Created glyph image for derge_དྷ_16.png
# Created glyph image for derge_ཏྶུ.png
# Created glyph image for derge_སྣ_100.png
# Created glyph image for derge_ཕྲ_1.png
# Created glyph image for derge_བྷྱུ.png
# Created glyph image for derge_ལུ_15.png
# Created glyph image for derge_རླ_12.png
# Created glyph image for derge_ལྟུ_16.png
# Created glyph image for derge_ཏྱ_11.png
# Created glyph image for derge_མྱུ_20.png
# Created glyph image for derge_སྨྱུ_11.png
# Created glyph image for derge_ཆུ_15.png
# Created glyph image for derge_རྦུ_2.png
# Created glyph image for derge_མོ_17.png
# Created glyph image for derge_རྩྭ_19.png
# Created glyph image for derge_པེ_3.png
# Created glyph image for derge_ཧྭ_57.png
# Created glyph image for derge_རྙ_28.png
# Created glyph image for derge_ཅུ_1.png
# Created glyph image for derge_འོ_11.png
# Created glyph image for derge_ནྠ_37.png
# Created glyph image for derge_ནཱ_19.png
# Created glyph image for derge_ཅོ_11.png
# Created glyph image for derge_ཐ_11.png
# Created glyph image for derge_ཡཱུ_5.png
# Created glyph image for derge_ཛུ_13.png
# Created glyph image for derge_ལི_1.png
# Created glyph image for derge_ནཱ_25.png
# Created glyph image for derge_ཨུ_100.png
# Created glyph image for derge_ཏྭ_1.png
# Created glyph image for derge_ཅྭ_17.png
# Created glyph image for derge_ཞ_14.png
# Created glyph image for derge_རླུ_100.png
# Created glyph image for derge_ཁུ_41.png
# Created glyph image for derge_ཅི_14.png
# Created glyph image for derge_ཏཱ_4.png
# Created glyph image for derge_བྦྷ.png
# Created glyph image for derge_སྟུ_20.png
# Created glyph image for derge_ཧཱ_11.png
# Created glyph image for derge_ཟི_91.png
# Created glyph image for derge_ཤྟ.png
# Created glyph image for derge_པཱུ_16.png
# Created glyph image for derge_ཙི_17.png
# Created glyph image for derge_སྣུ_6.png
# Created glyph image for derge_གཱ_11.png
# Created glyph image for derge_བྱཱ_25.png
# Created glyph image for derge_ཏཱ_26.png
# Created glyph image for derge_ཇེ_15.png
# Created glyph image for derge_སྔུ_52.png
# Created glyph image for derge_རུ_10.png
# Created glyph image for derge_ལྗ_14.png
# Created glyph image for derge_ཎྱ_14.png
# Created glyph image for derge_ཧཱ_39.png
# Created glyph image for derge_ཥྛུ.png
# Created glyph image for derge_ྡ_2.png
# Created glyph image for derge_སྔུ_46.png
# Created glyph image for derge_ལླཱ_19.png
# Created glyph image for derge_ཊུ_25.png
# Created glyph image for derge_ཝུ_68.png
# Created glyph image for derge_ལྗ_100.png
# Created glyph image for derge_པོ_27.png
# Created glyph image for derge_ཧྲ_49.png
# Created glyph image for derge_ལྷ_4.png
# Created glyph image for derge_ལྗ_16.png
# Created glyph image for derge_རུ_12.png
# Created glyph image for derge_ཕྲ_10.png
# Created glyph image for derge_པཱུ_14.png
# Created glyph image for derge_རེ_17.png
# Created glyph image for derge_ཊུ_19.png
# Created glyph image for derge_པི_36.png
# Created glyph image for derge_ཏྦྷ.png
# Created glyph image for derge_ཟི_93.png
# Created glyph image for derge_ཎྜ_19.png
# Created glyph image for derge_ཏཱ_30.png
# Created glyph image for derge_ཇེ_17.png
# Created glyph image for derge_ཏཱ_24.png
# Created glyph image for derge_ལླཱ_27.png
# Created glyph image for derge_མྤྲ.png
# Created glyph image for derge_སྣུ_4.png
# Created glyph image for derge_གཱ_13.png
# Created glyph image for derge_ཙི_15.png
# Created glyph image for derge_ཞ_16.png
# Created glyph image for derge_ཅྭ_15.png
# Created glyph image for derge_ནྡྲ_91.png
# Created glyph image for derge_ནྱུ.png
# Created glyph image for derge_ཌྷ_12.png
# Created glyph image for derge_ཀླུ_1.png
# Created glyph image for derge_འོ_13.png
# Created glyph image for derge_ཛུ_11.png
# Created glyph image for derge_ཡཱུ_7.png
# Created glyph image for derge_ཐ_13.png
# Created glyph image for derge_ཝུ_83.png
# Created glyph image for derge_ཅོ_13.png
# Created glyph image for derge_རླ_10.png
# Created glyph image for derge_ལུ_17.png
# Created glyph image for derge_རྗ_13.png
# Created glyph image for derge_མོ_15.png
# Created glyph image for derge_ཏྠཱ_3.png
# Created glyph image for derge_ཆུ_17.png
# Created glyph image for derge_ྣ_2.png
# Created glyph image for derge_རྟུ_14.png
# Created glyph image for derge_ཆེ_12.png
# Created glyph image for derge_མྦུ_53.png
# Created glyph image for derge_རྡ_1.png
# Created glyph image for derge_ལྕ_4.png
# Created glyph image for derge_གྱ_18.png
# Created glyph image for derge_སྤ_1.png
# Created glyph image for derge_ལྟུ_28.png
# Created glyph image for derge_ཕྲ_3.png
# Created glyph image for derge_ལེ_12.png
# Created glyph image for derge_མྦྷ_35.png
# Created glyph image for derge_ཏྶ_32.png
# Created glyph image for derge_དྷ_14.png
# Created glyph image for derge_རྡྲཱ.png
# Created glyph image for derge_རྨྱ_2.png
# Created glyph image for derge_ཡི_13.png
# Created glyph image for derge_དྷཱ_13.png
# Created glyph image for derge_པྟ_4.png
# Created glyph image for derge_ཆ_17.png
# Created glyph image for derge_ངི_13.png
# Created glyph image for derge_ར_14.png
# Created glyph image for derge_ྚ_2.png
# Created glyph image for derge_ཚེ_11.png
# Created glyph image for derge_ངྒ_43.png
# Created glyph image for derge_ཚུ_14.png
# Created glyph image for derge_ཟི_1.png
# Created glyph image for derge_ངོ_16.png
# Created glyph image for derge_རྡྷྱ.png
# Created glyph image for derge_ཛྫ_4.png
# Created glyph image for derge_དྲུ_12.png
# Created glyph image for derge_ཙཱ_2.png
# Created glyph image for derge_ཏྶྛ.png
# Created glyph image for derge_ནྟྱཱ.png
# Created glyph image for derge_ཉི_18.png
# Created glyph image for derge_རྱ_15.png
# Created glyph image for derge_སྒྲུ_23.png
# Created glyph image for derge_གླ_21.png
# Created glyph image for derge_ཐོ_13.png
# Created glyph image for derge_གྲྭ_12.png
# Created glyph image for derge_ཇ_100.png
# Created glyph image for derge_ྲ_9.png
# Created glyph image for derge_བྷཱུ_95.png
# Created glyph image for derge_རྦུ.png
# Created glyph image for derge_ཐི_16.png
# Created glyph image for derge_སྒྱ_12.png
# Created glyph image for derge_ཚཱ_24.png
# Created glyph image for derge_ཁྱུ_1.png
# Created glyph image for derge_ྜ_4.png
# Created glyph image for derge_ཀྲཱ.png
# Created glyph image for derge_ཛྙཱ_76.png
# Created glyph image for derge_བྷ.png
# Created glyph image for derge_ཟུ_19.png
# Created glyph image for derge_ནི_1.png
# Created glyph image for derge_ཤི_22.png
# Created glyph image for derge_ཤྭ_21.png
# Created glyph image for derge_ང_12.png
# Created glyph image for derge_འ_11.png
# Created glyph image for derge_ཏྟཱ_34.png
# Created glyph image for derge_ནྟུ_84.png
# Created glyph image for derge_ཊ_17.png
# Created glyph image for derge_ཀྵ_19.png
# Created glyph image for derge_ཛྭ_2.png
# Created glyph image for derge_རྦྷ_1.png
# Created glyph image for derge_ཀྲ_10.png
# Created glyph image for derge_བྠ.png
# Created glyph image for derge_ཟླུ_22.png
# Created glyph image for derge_རྞ_7.png
# Created glyph image for derge_ངྐུ_3.png
# Created glyph image for derge_ཀྟ_23.png
# Created glyph image for derge_དྒུ.png
# Created glyph image for derge_རླུ_17.png
# Created glyph image for derge_ལྱ_2.png
# Created glyph image for derge_ཙི_100.png
# Created glyph image for derge_གྷླ.png
# Created glyph image for derge_ཏཱུ.png
# Created glyph image for derge_ཏུ_14.png
# Created glyph image for derge_མི_100.png
# Created glyph image for derge_ལྕ_13.png
# Created glyph image for derge_བྱུ_17.png
# Created glyph image for derge_ཟླ_2.png
# Created glyph image for derge_དོ_16.png
# Created glyph image for derge_སྐ_12.png
# Created glyph image for derge_ཛ_1.png
# Created glyph image for derge_དི_13.png
# Created glyph image for derge_སླ_18.png
# Created glyph image for derge_རྒྱ_18.png
# Created glyph image for derge_ཏེ_11.png
# Created glyph image for derge_ཅོ_100.png
# Created glyph image for derge_སྡུ_1.png
# Created glyph image for derge_ངོ_100.png
# Created glyph image for derge_ྞ_6.png
# Created glyph image for derge_ཨི_10.png
# Created glyph image for derge_ཨོ_29.png
# Created glyph image for derge_༈_70.png
# Created glyph image for derge_གྱུ_10.png
# Created glyph image for derge_ཥྤ_14.png
# Created glyph image for derge_ནེ_12.png
# Created glyph image for derge_ྩ_9.png
# Created glyph image for derge_ཥྛ_47.png
# Created glyph image for derge_ཀོ_22.png
# Created glyph image for derge_དྲ_100.png
# Created glyph image for derge_ནུ_17.png
# Created glyph image for derge_ཌཱུ_1.png
# Created glyph image for derge_ཁྲ_15.png
# Created glyph image for derge_དྡྷ_18.png
# Created glyph image for derge_ཨོ_14.png
# Created glyph image for derge_ཁཱ_66.png
# Created glyph image for derge_སྲུ_19.png
# Created glyph image for derge_ཞེ_18.png
# Created glyph image for derge_ཉྕ.png
# Created glyph image for derge_ཁྲ_14.png
# Created glyph image for derge_ཞུ_21.png
# Created glyph image for derge_ཥྛ_46.png
# Created glyph image for derge_ཧཱུ_29.png
# Created glyph image for derge_ནུ_16.png
# Created glyph image for derge_ཀོ_23.png
# Created glyph image for derge_ནེ_13.png
# Created glyph image for derge_ཥྤ_15.png
# Created glyph image for derge_ཨོ_28.png
# Created glyph image for derge_ཞེ_24.png
# Created glyph image for derge_ཉུ_2.png
# Created glyph image for derge_ྩ_8.png
# Created glyph image for derge_ྞ_7.png
# Created glyph image for derge_ཨི_11.png
# Created glyph image for derge_ཁྲུ_100.png
# Created glyph image for derge_ཤེ_2.png
# Created glyph image for derge_ཀེ_1.png
# Created glyph image for derge_ཙྪུ.png
# Created glyph image for derge_དི_12.png
# Created glyph image for derge_སྐ_13.png
# Created glyph image for derge_ཊཱ_14.png
# Created glyph image for derge_སོ_1.png
# Created glyph image for derge_སྣུ_11.png
# Created glyph image for derge_ལྱ_11.png
# Created glyph image for derge_བྱུ_16.png
# Created glyph image for derge_སྣུ_39.png
# Created glyph image for derge_ཏུ_15.png
# Created glyph image for derge_གྷུ_1.png
# Created glyph image for derge_གུ_22.png
# Created glyph image for derge_ལུ_100.png
# Created glyph image for derge_བྷུ_90.png
# Created glyph image for derge_ལྱ_3.png
# Created glyph image for derge_རླུ_16.png
# Created glyph image for derge_ཧུ_22.png
# Created glyph image for derge_གྷྲ.png
# Created glyph image for derge_སྐྲུ_65.png
# Created glyph image for derge_རྞ_6.png
# Created glyph image for derge_ཟླུ_23.png
# Created glyph image for derge_ཀཱ_100.png
# Created glyph image for derge_ཀྟ_22.png
# Created glyph image for derge_ཀྵ_18.png
# Created glyph image for derge_ཚཱ_19.png
# Created glyph image for derge_ཊ_16.png
# Created glyph image for derge_ཛྱ_17.png
# Created glyph image for derge_ཀྲ_11.png
# Created glyph image for derge_ཁཱ_100.png
# Created glyph image for derge_ཤྭ_20.png
# Created glyph image for derge_ཤི_23.png
# Created glyph image for derge_།།.png
# Created glyph image for derge_ཟུ_18.png
# Created glyph image for derge_༅_31.png
# Created glyph image for derge_ཏྟཱ_35.png
# Created glyph image for derge_འ_10.png
# Created glyph image for derge_ྛ_10.png
# Created glyph image for derge_ཚཱ_31.png
# Created glyph image for derge_ང_13.png
# Created glyph image for derge_༅_25.png
# Created glyph image for derge_ཟེ_21.png
# Created glyph image for derge_ཛྙཱ_77.png
# Created glyph image for derge_ྜ_5.png
# Created glyph image for derge_ཐི_17.png
# Created glyph image for derge_དྲ_19.png
# Created glyph image for derge_མྦ_5.png
# Created glyph image for derge_ྲ_8.png
# Created glyph image for derge_ཏྐ_21.png
# Created glyph image for derge_ༀ_4.png
# Created glyph image for derge_རྱ_14.png
# Created glyph image for derge_ཐོ_12.png
# Created glyph image for derge_རྒྱ_100.png
# Created glyph image for derge_ལྤྱ.png
# Created glyph image for derge_ངྒ_56.png
# Created glyph image for derge_ཥ_20.png
# Created glyph image for derge_དཱུ_23.png
# Created glyph image for derge_དཱུ_37.png
# Created glyph image for derge_ཚུ_15.png
# Created glyph image for derge_ྗ_10.png
# Created glyph image for derge_ངོ_17.png
# Created glyph image for derge_ར_15.png
# Created glyph image for derge_ངི_12.png
# Created glyph image for derge_ཆ_16.png
# Created glyph image for derge_ཚེ_10.png
# Created glyph image for derge_ྚ_3.png
# Created glyph image for derge_དྷཱ_12.png
# Created glyph image for derge_ཡི_12.png
# Created glyph image for derge_སྤྲ_13.png
# Created glyph image for derge_བླ_19.png
# Created glyph image for derge_ལེ_13.png
# Created glyph image for derge_རྙ_17.png
# Created glyph image for derge_ཕྲ_2.png
# Created glyph image for derge_དྷ_15.png
# Created glyph image for derge_མྦྷ_34.png
# Created glyph image for derge_གྱ_19.png
# Created glyph image for derge_ལླཱ_9.png
# Created glyph image for derge_ཆེ_13.png
# Created glyph image for derge_མྦུ_52.png
# Created glyph image for derge_ནྟྲ_10.png
# Created glyph image for derge_མི_11.png
# Created glyph image for derge_ལྟུ_29.png
# Created glyph image for derge_ཀྵྱཱ.png
# Created glyph image for derge_སྩ_21.png
# Created glyph image for derge_མོ_14.png
# Created glyph image for derge_རྟུ_15.png
# Created glyph image for derge_ྣ_3.png
# Created glyph image for derge_ཆུ_16.png
# Created glyph image for derge_ལུ_16.png
# Created glyph image for derge_རླ_11.png
# Created glyph image for derge_ལྟུ_15.png
# Created glyph image for derge_ཏྱ_12.png
# Created glyph image for derge_ཙྪཱ_3.png
# Created glyph image for derge_ཇི_1.png
# Created glyph image for derge_དུ_100.png
# Created glyph image for derge_ནྠ_20.png
# Created glyph image for derge_ཛུ_10.png
# Created glyph image for derge_ཛྫ_13.png
# Created glyph image for derge_ཅོ_12.png
# Created glyph image for derge_ཐ_12.png
# Created glyph image for derge_ུ_11.png
# Created glyph image for derge_ཡཱུ_6.png
# Created glyph image for derge_སྟ_2.png
# Created glyph image for derge_ཐུ_100.png
# Created glyph image for derge_ཀཾ_26.png
# Created glyph image for derge_འོ_12.png
# Created glyph image for derge_ཙ_22.png
# Created glyph image for derge_ནྡྲ_84.png
# Created glyph image for derge_ཅྭ_14.png
# Created glyph image for derge_ཞ_17.png
# Created glyph image for derge_བྱཱ_26.png
# Created glyph image for derge_སྤྲུ_14.png
# Created glyph image for derge_པྲཱ_9.png
# Created glyph image for derge_ཇེ_16.png
# Created glyph image for derge_ཙི_14.png
# Created glyph image for derge_གཱ_12.png
# Created glyph image for derge_རེ_16.png
# Created glyph image for derge_པཱུ_15.png
# Created glyph image for derge_ཡྱ.png
# Created glyph image for derge_སྦཱ.png
# Created glyph image for derge_ཎྜ_18.png
# Created glyph image for derge_ཟི_92.png
# Created glyph image for derge_རྣ_2.png
# Created glyph image for derge_པི_37.png
# Created glyph image for derge_ྡ_1.png
# Created glyph image for derge_ཧྲ_48.png
# Created glyph image for derge_རུ_13.png
# Created glyph image for derge_ཊུ_30.png
# Created glyph image for derge_ལྗ_17.png
# Created glyph image for derge_ཝེ_44.png
# Created glyph image for derge_ཇུ_13.png
# Glyph image creation completed.
